# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanthi773/pandas/blob/main/loc_and_iloc_practices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-eb1872bb-c6f7-4bee-a105-89bfdd1f35e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb1872bb-c6f7-4bee-a105-89bfdd1f35e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/Detaism data.csv')
print(df)
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/Detaism data.csv')
print(df.Category)
# Out:
# 0       Electronics
# 1         Furniture
# 2         Furniture
# 3       Electronics
# 4       Electronics
#            ...
# 1495       Clothing
# 1496       Clothing
# 1497    Electronics
# 1498       Clothing
# 1499      Furniture
# Name: Category, Length: 1500, dtype: object

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
cols=["Category","Amount"]
df2=df1[cols]
print(df2)
# Out:
#          Category  Amount
# 0     Electronics    1096
# 1       Furniture    5729
# 2       Furniture    2927
# 3     Electronics    2847
# 4     Electronics    2617
# ...           ...     ...
# 1495     Clothing       7
# 1496     Clothing    3151
# 1497  Electronics    4141
# 1498     Clothing       7
# 1499    Furniture    4363
#
# [1500 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv('/content/Detaism data.csv')
total=df['Quantity'].sum()
print(total)
# Out:
# 5615

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
print(df1)
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
category=df1["Category"]=="Electronics"
print(df1[category])
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# 11    B-25887    2125    -234         6  Electronics          Printers
# 12    B-25923    3873    -891         6  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1484  B-25910     850    -289         5  Electronics  Electronic Games
# 1485  B-25830    1063      64         7  Electronics            Phones
# 1486  B-25978    1063    -175         4  Electronics  Electronic Games
# 1490  B-25858    2457     665        11  Electronics  Electronic Games
# 1497  B-25973    4141    1698        13  Electronics          Printers
#
#       PaymentMode
# 0             COD
# 3     Credit Card
# 4     Credit Card
# 11            EMI
# ...

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
sub_categ=df1["Sub-Category"]=="Phones"
print(df1[sub_categ])
# Out:
#      Order ID  Amount  Profit  Quantity     Category Sub-Category  PaymentMode
# 4     B-25602    2617    1151         4  Electronics       Phones  Credit Card
# 12    B-25923    3873    -891         6  Electronics       Phones  Credit Card
# 25    B-25830    1954     782         3  Electronics       Phones  Credit Card
# 32    B-26022    1824    1303         8  Electronics       Phones  Credit Card
# 42    B-25681    1625     -77         3  Electronics       Phones          EMI
# ...       ...     ...     ...       ...          ...          ...          ...
# 1389  B-25630     143    -129         2  Electronics       Phones          COD
# 1408  B-25633     249    -130         4  Electronics       Phones          UPI
# 1433  B-25639    1629    -153         3  Electronics       Phones          COD
# 1438  B-25919     977    -244         7  Electronics       Phones          COD
# 1485  B-25830    1063      64         7  Electronics       Phones          EMI
#
# [83 rows x 7 columns]

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
s=df1.iloc[0]
print(s)
# Out:
# Order ID                 B-25681
# Amount                      1096
# Profit                       658
# Quantity                       7
# Category             Electronics
# Sub-Category    Electronic Games
# PaymentMode                  COD
# Name: 0, dtype: object

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
s=df1.iloc[1]
print(s)
# Out:
# Order ID          B-26055
# Amount               5729
# Profit                 64
# Quantity               14
# Category        Furniture
# Sub-Category       Chairs
# PaymentMode           EMI
# Name: 1, dtype: object

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
s=df1.iloc[-1]
print(s)
# Out:
# Order ID          B-25993
# Amount               4363
# Profit                305
# Quantity                5
# Category        Furniture
# Sub-Category       Tables
# PaymentMode           EMI
# Name: 1499, dtype: object

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df2=df1.iloc[:,0]
print(df2)
# Out:
# 0       B-25681
# 1       B-26055
# 2       B-25955
# 3       B-26093
# 4       B-25602
#          ...
# 1495    B-25700
# 1496    B-25757
# 1497    B-25973
# 1498    B-25698
# 1499    B-25993
# Name: Order ID, Length: 1500, dtype: object

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df2=df1.iloc[:,1]
print(df2)
# Out:
# 0       1096
# 1       5729
# 2       2927
# 3       2847
# 4       2617
#         ...
# 1495       7
# 1496    3151
# 1497    4141
# 1498       7
# 1499    4363
# Name: Amount, Length: 1500, dtype: int64

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df2=df1.iloc[:,-1]
print(df2)
# Out:
# 0               COD
# 1               EMI
# 2               EMI
# 3       Credit Card
# 4       Credit Card
#            ...
# 1495            COD
# 1496            EMI
# 1497            COD
# 1498            COD
# 1499            EMI
# Name: PaymentMode, Length: 1500, dtype: object

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df2=df1.iloc[0:5]
print(df2)
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681    1096     658         7  Electronics  Electronic Games
# 1  B-26055    5729      64        14    Furniture            Chairs
# 2  B-25955    2927     146         8    Furniture         Bookcases
# 3  B-26093    2847     712         8  Electronics          Printers
# 4  B-25602    2617    1151         4  Electronics            Phones
#
#    PaymentMode
# 0          COD
# 1          EMI
# 2          EMI
# 3  Credit Card
# 4  Credit Card

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df2=df1.iloc[:,0:2]
print(df2)
# Out:
#      Order ID  Amount
# 0     B-25681    1096
# 1     B-26055    5729
# 2     B-25955    2927
# 3     B-26093    2847
# 4     B-25602    2617
# ...       ...     ...
# 1495  B-25700       7
# 1496  B-25757    3151
# 1497  B-25973    4141
# 1498  B-25698       7
# 1499  B-25993    4363
#
# [1500 rows x 2 columns]

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df2=df1.iloc[:,0:3]
print(df2)
# Out:
#      Order ID  Amount  Profit
# 0     B-25681    1096     658
# 1     B-26055    5729      64
# 2     B-25955    2927     146
# 3     B-26093    2847     712
# 4     B-25602    2617    1151
# ...       ...     ...     ...
# 1495  B-25700       7      -3
# 1496  B-25757    3151     -35
# 1497  B-25973    4141    1698
# 1498  B-25698       7      -2
# 1499  B-25993    4363     305
#
# [1500 rows x 3 columns]

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df2=df1.iloc[0:5,0:2]
print(df2)
# Out:
#   Order ID  Amount
# 0  B-25681    1096
# 1  B-26055    5729
# 2  B-25955    2927
# 3  B-26093    2847
# 4  B-25602    2617

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df2=df1.iloc[0:5,0:3]
print(df2)
# Out:
#   Order ID  Amount  Profit
# 0  B-25681    1096     658
# 1  B-26055    5729      64
# 2  B-25955    2927     146
# 3  B-26093    2847     712
# 4  B-25602    2617    1151

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df2=df1.iloc[0:2,0:3]
print(df2)
# Out:
#   Order ID  Amount  Profit
# 0  B-25681    1096     658
# 1  B-26055    5729      64

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df1.set_index("Category",inplace=True)
print(df1)
# Out:
#             Order ID  Amount  Profit  Quantity      Sub-Category  PaymentMode
# Category
# Electronics  B-25681    1096     658         7  Electronic Games          COD
# Furniture    B-26055    5729      64        14            Chairs          EMI
# Furniture    B-25955    2927     146         8         Bookcases          EMI
# Electronics  B-26093    2847     712         8          Printers  Credit Card
# Electronics  B-25602    2617    1151         4            Phones  Credit Card
# ...              ...     ...     ...       ...               ...          ...
# Clothing     B-25700       7      -3         2       Hankerchief          COD
# Clothing     B-25757    3151     -35         7          Trousers          EMI
# Electronics  B-25973    4141    1698        13          Printers          COD
# Clothing     B-25698       7      -2         1       Hankerchief          COD
# Furniture    B-25993    4363     305         5            Tables          EMI
#
# [1500 rows x 6 columns]

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df1.set_index("Category",inplace=True)

a="Furniture"
df2=df1.loc[a]
print(df2.head(10))
# Out:
#           Order ID  Amount  Profit  Quantity Sub-Category  PaymentMode
# Category
# Furniture  B-26055    5729      64        14       Chairs          EMI
# Furniture  B-25955    2927     146         8    Bookcases          EMI
# Furniture  B-25756     729    -492         5    Bookcases          UPI
# Furniture  B-25761    2188    1050         5    Bookcases  Credit Card
# Furniture  B-25786    1854     433         5    Bookcases  Credit Card
# Furniture  B-25853    2093     721         5       Chairs  Credit Card
# Furniture  B-25910    1622    -624         5       Tables  Credit Card
# Furniture  B-25686    1829     -56         6       Tables  Credit Card
# Furniture  B-26048    1461     202         5       Tables          EMI
# Furniture  B-26003    1745     122         2       Tables  Credit Card

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df1.set_index("Category",inplace=True)

a=['Furniture','Clothing']
df2=df1.loc[a]
print(df2)
# Out:
#           Order ID  Amount  Profit  Quantity Sub-Category  PaymentMode
# Category
# Furniture  B-26055    5729      64        14       Chairs          EMI
# Furniture  B-25955    2927     146         8    Bookcases          EMI
# Furniture  B-25756     729    -492         5    Bookcases          UPI
# Furniture  B-25761    2188    1050         5    Bookcases  Credit Card
# Furniture  B-25786    1854     433         5    Bookcases  Credit Card
# ...            ...     ...     ...       ...          ...          ...
# Clothing   B-25873       7       1         1  Hankerchief          COD
# Clothing   B-25740       7       0         2        Skirt          COD
# Clothing   B-25700       7      -3         2  Hankerchief          COD
# Clothing   B-25757    3151     -35         7     Trousers          EMI
# Clothing   B-25698       7      -2         1  Hankerchief          COD
#
# [1192 rows x 6 columns]

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
df1.set_index("Category",inplace=True)

a=['Furniture','Clothing']
b=['Amount','Profit']
df2=df1.loc[a,b]
print(df2)
# Out:
#            Amount  Profit
# Category
# Furniture    5729      64
# Furniture    2927     146
# Furniture     729    -492
# Furniture    2188    1050
# Furniture    1854     433
# ...           ...     ...
# Clothing        7       1
# Clothing        7       0
# Clothing        7      -3
# Clothing     3151     -35
# Clothing        7      -2
#
# [1192 rows x 2 columns]

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
a=df1['Category']=='Clothing'
df2=df1.loc[a]
print(df2.head())
# Out:
#   Order ID  Amount  Profit  Quantity  Category Sub-Category  PaymentMode
# 5  B-25881    2244     247         4  Clothing     Trousers  Credit Card
# 6  B-25696     275    -275         4  Clothing        Saree          COD
# 7  B-25687     387    -213         5  Clothing        Saree          UPI
# 8  B-25643      50     -44         2  Clothing  Hankerchief          UPI
# 9  B-25851     135     -54         5  Clothing        Kurti          COD

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
a=df1['Category']=='Clothing'
df2=df1.loc[a,['Order ID','Amount']]
print(df2.head())
# Out:
#   Order ID  Amount
# 5  B-25881    2244
# 6  B-25696     275
# 7  B-25687     387
# 8  B-25643      50
# 9  B-25851     135

# %%
import pandas as pd
df1=pd.read_csv('/content/Detaism data.csv')
a=df1['Category']=='Clothing'
df2=df1.loc[a,['PaymentMode','Profit']]
print(df2.head())
# Out:
#    PaymentMode  Profit
# 5  Credit Card     247
# 6          COD    -275
# 7          UPI    -213
# 8          UPI     -44
# 9          COD     -54
