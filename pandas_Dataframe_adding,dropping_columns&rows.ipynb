# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanthi773/pandas/blob/main/pandas_Dataframe_adding%2Cdropping_columns%26rows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c55a3e2e-1332-433b-b3f1-84a4b3ff22f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c55a3e2e-1332-433b-b3f1-84a4b3ff22f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/sales8.csv")
print(df.head(5))
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity
# 0         65999         1
# 1         63000         2
# 2         75999         1
# 3         60000         2
# 4         69999         3

# %%
import pandas as pd
df=pd.read_csv("/content/sales8.csv")
df["status"]="delivered"
print(df.head())
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity     status
# 0         65999         1  delivered
# 1         63000         2  delivered
# 2         75999         1  delivered
# 3         60000         2  delivered
# 4         69999         3  delivered

# %%
import pandas as pd
df=pd.read_csv("/content/sales8.csv")
df["Total cost"]=df["Product cost"]*df["Quantity"]
print(df.head(5))
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity  Total cost
# 0         65999         1       65999
# 1         63000         2      126000
# 2         75999         1       75999
# 3         60000         2      120000
# 4         69999         3      209997

# %%
import pandas as pd
df=pd.read_csv("/content/sales8.csv")

def total(df):
   t=df["Product cost"]*df["Quantity"]
   return t
df["Total cost"]=df.apply(total,axis=1)

print(df.head())
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity  Total cost
# 0         65999         1       65999
# 1         63000         2      126000
# 2         75999         1       75999
# 3         60000         2      120000
# 4         69999         3      209997

# %%
import pandas as pd
df=pd.read_csv("/content/sales8.csv")
print(df.head())
new=df["Product cost"]*df["Quantity"]
df.insert(5,"Total cost",new)


print()
print(df.head(5))
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity
# 0         65999         1
# 1         63000         2
# 2         75999         1
# 3         60000         2
# 4         69999         3
#
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# ...

# %%
import pandas as pd
df1=pd.read_csv("/content/sales8.csv")
df2=df1.drop(columns="Customer name")

print(df1.head())
print()
print(df2.head())
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity
# 0         65999         1
# 1         63000         2
# 2         75999         1
# 3         60000         2
# 4         69999         3
#
#    Order Id  Customer Id                Product name  Product cost  Quantity
# 0    192837            3                   LG Mobile         65999         1
# 1    192838           19        Apple iPad 10.2-inch         63000         2
# 2    192839           12      34in Ultrawide Monitor         75999         1
# 3    192840           20                   iPhone 11         60000         2
# ...

# %%
import pandas as pd
df1=pd.read_csv("/content/sales8.csv")
df2=df1.drop(["Customer name","Product name"],axis=1)

print(df1.head())
print()
print(df2.head())
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity
# 0         65999         1
# 1         63000         2
# 2         75999         1
# 3         60000         2
# 4         69999         3
#
#    Order Id  Customer Id  Product cost  Quantity
# 0    192837            3         65999         1
# 1    192838           19         63000         2
# 2    192839           12         75999         1
# 3    192840           20         60000         2
# 4    192841           10         69999         3

# %%
import pandas as pd
df1=pd.read_csv("/content/sales8.csv")
df2=df1.drop(3,axis=0)

print(df1.head())
print()
print(df2.head())
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity
# 0         65999         1
# 1         63000         2
# 2         75999         1
# 3         60000         2
# 4         69999         3
#
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 4    192841         Vinay           10  Bose SoundSport Headphones
# ...

# %%
import pandas as pd
df1=pd.read_csv("/content/sales8.csv")
df2=df1.drop([1,2],axis=0)

print(df1.head())
print()
print(df2.head())
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity
# 0         65999         1
# 1         63000         2
# 2         75999         1
# 3         60000         2
# 4         69999         3
#
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
# 5    192842         Vinay           10                20in Monitor
# ...

# %%
import pandas as pd
df1=pd.read_csv("/content/sales8.csv")
df2=df1.drop([2,4],axis=0)

print(df1.head())
print()
print(df2.head())
# Out:
#    Order Id Customer name  Customer Id                Product name  \
# 0    192837         Veeru            3                   LG Mobile
# 1    192838       Neelima           19        Apple iPad 10.2-inch
# 2    192839        Balaji           12      34in Ultrawide Monitor
# 3    192840        Shahid           20                   iPhone 11
# 4    192841         Vinay           10  Bose SoundSport Headphones
#
#    Product cost  Quantity
# 0         65999         1
# 1         63000         2
# 2         75999         1
# 3         60000         2
# 4         69999         3
#
#    Order Id Customer name  Customer Id          Product name  Product cost  \
# 0    192837         Veeru            3             LG Mobile         65999
# 1    192838       Neelima           19  Apple iPad 10.2-inch         63000
# 3    192840        Shahid           20             iPhone 11         60000
# 5    192842         Vinay           10          20in Monitor         65999
# ...
